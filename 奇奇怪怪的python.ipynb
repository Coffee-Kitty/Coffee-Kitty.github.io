# %%
# %pip install instaviz
# Out:
# ...
#   Using cached instaviz-0.6.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached bottle-0.13.4-py2.py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached instaviz-0.6.0-py3-none-any.whl (462 kB)
# Using cached bottle-0.13.4-py2.py3-none-any.whl (103 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [instaviz]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import instaviz
def example():
    a=1
    b=a+1
    return b
instaviz.show(example)
# Out:
# Bottle v0.13.4 server starting up (using WSGIRefServer())...
# Listening on http://localhost:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET / HTTP/1.1" 200 22148
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/bootstrap.min.css HTTP/1.1" 200 155758
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/vis-network.min.css HTTP/1.1" 200 14426
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/json2html.css HTTP/1.1" 200 752
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/vis.js HTTP/1.1" 200 1854177
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/jquery.min.js HTTP/1.1" 200 97163
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/jquery.json2html.js HTTP/1.1" 200 4626
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/json2html.js HTTP/1.1" 200 13600
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /static/node.js HTTP/1.1" 200 2528
# 127.0.0.1 - - [28/Apr/2026 15:45:14] "GET /favicon.ico HTTP/1.1" 404 748
# ...
